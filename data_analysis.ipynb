# %%
import yfinance as yf

# %%
import yfinance as yf
import pandas as pd

# %%
ibr50 = pd.read_csv('IBXLDia_19-08-24.csv',sep=';',encoding='latin1')
stock_list = [stock + '.SA' for stock in ibr50.iloc[:,0].to_list()]
data = yf.download(stock_list, start='2015-01-01',interval='1d',rounding=True)
out = data.stack().reset_index(level=1, names=["", "Ticker"]).sort_values(by=["Ticker",'Date']).reset_index()
# Out:
# [*********************100%***********************]  48 of 48 completed

# %%
out['AdjRatio'] = round(out['Adj Close']/out['Close'],4)
out['AdjHigh'] = round(out['AdjRatio']*out['High'],2)
out['AdjLow'] = round(out['AdjRatio']*out['Low'],2)
out['AdjOpen'] = round(out['AdjRatio']*out['Open'],2)
out['Low2High'] = round(out['AdjHigh']/out['AdjLow']-1,4)*100
out['Open2Close'] = round(out['Adj Close']/out['AdjOpen']-1,4)*100
out['CloseChange'] = out['Adj Close'].pct_change()*100
out['VolumeChange'] = out['Volume'].pct_change()*100

out.drop(['Close','High','Low','Open'],axis=1,inplace=True)

# %%
out['CloseChange'] = out.groupby('Ticker')['Adj Close'].pct_change()*100
out['VolumeChange'] = out.groupby('Ticker')['Volume'].pct_change()*100

# %%
out
# Out:
#              Date    Ticker  Adj Close      Volume  AdjRatio  AdjHigh  AdjLow  \
# 0      2015-01-02  ABEV3.SA      10.96  19396500.0    0.6841    11.33   10.79
# 1      2015-01-05  ABEV3.SA      10.77  13795900.0    0.6847    10.93   10.64
# 2      2015-01-06  ABEV3.SA      11.18  18610500.0    0.6846    11.24   10.65
# 3      2015-01-07  ABEV3.SA      11.33  20493500.0    0.6842    11.44   11.04
# 4      2015-01-08  ABEV3.SA      12.02   9054500.0    0.7267    12.12   11.82
# ...           ...       ...        ...         ...       ...      ...     ...
# 104279 2024-08-12  WEGE3.SA      50.58   8193400.0    1.0000    50.77   49.79
# 104280 2024-08-13  WEGE3.SA      51.13  10203100.0    1.0000    52.29   50.82
# 104281 2024-08-14  WEGE3.SA      51.54   7557200.0    1.0000    51.81   50.90
# 104282 2024-08-15  WEGE3.SA      52.70   6993700.0    1.0000    53.08   51.88
# 104283 2024-08-16  WEGE3.SA      53.25  10598700.0    1.0000    53.98   52.40
#
#         AdjOpen  Low2High  Open2Close  CloseChange  VolumeChange
# 0         11.04      5.00       -0.72          NaN           NaN
# 1         10.89      2.73       -1.10    -1.733577    -28.874281
# 2         10.77      5.54        3.81     3.806871     34.898774
# 3         11.18      3.62        1.34     1.341682     10.117944
# 4         11.94      2.54        0.67     6.090026    -55.817698
# ...         ...       ...         ...          ...           ...
# 104279    50.07      1.97        1.02     1.770624      6.485236
# 104280    50.98      2.89        0.29     1.087386     24.528279
# 104281    51.16      1.79        0.74     0.801878    -25.932315
# 104282    51.97      2.31        1.40     2.250679     -7.456465
# 104283    52.98      3.02        0.51     1.043643     51.546392
#
# [104284 rows x 12 columns]
